# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

# %%
#data augmentation and normalisation
stats = ((0.1307 ), (0.3081)) #these will be used as mean and std dev of mnist data

train_transformation = transforms.Compose([#transforms.RandomCrop(28,padding=4,padding_mode='reflect'),
                                           #transforms.RandomHorizontalFlip(),
                                           transforms.ToTensor(),
                                           transforms.Normalize(*stats,inplace=True)])

# %%
down_train_dataset = datasets.MNIST(root='data/', transform = train_transformation)
# Out:
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
type(down_train_dataset[0])
# Out:
# tuple

# %%
down_train_dataset[0][1]
# Out:
# 5

# %%
down_test_dataset = datasets.MNIST(root='data/',train = False, transform = train_transformation)

# %% [markdown]
# # full datatset

# %%
down_dataset = down_train_dataset + down_test_dataset

# %%
type(down_dataset)
# Out:
# torch.utils.data.dataset.ConcatDataset

# %%
len(down_dataset)
# Out:
# 70000

# %%
batch_size = 128

# %%
full_image_loader = DataLoader(down_dataset, batch_size, shuffle=True, num_workers = 1, pin_memory = True)

# %% [markdown]
# # we wont use device loader as no GPU

# %% [markdown]
# # lets look at the images

# %%
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1] + stats[0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(full_image_loader)

# %%
# Discriminator network

# %%
discriminator = nn.Sequential(
    #in = 1,28,28
    nn.Conv2d(1,8,kernel_size = 3, stride = 1, padding = 1, bias = False), #for GAN no need of bias.\n",
    nn.BatchNorm2d(8),
    nn.LeakyReLU(0.01, inplace=True),
    #out = 8,28,28

    nn.Conv2d(8,64,kernel_size = 4, stride = 2, padding = 1, bias = False), #for GAN no need of bias.\n",
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.01, inplace=True),
    #out = 64,14,14\n",

    nn.Conv2d(64,128,kernel_size = 4, stride = 2, padding = 1, bias = False), #for GAN no need of bias.\n",
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.01, inplace=True),
    #out= 128,7,7\n",

    nn.Conv2d(128,256, kernel_size = 3, stride = 2, padding = 1, bias = False), #for GAN no need of bias.\n",
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.01, inplace=True),
    #out 256,4,4

    nn.Conv2d(256,1,kernel_size = 4, stride = 1, padding = 0, bias = False), #for GAN no need of bias.\n",
    #out 1,1,1

    nn.Flatten(),
    nn.Sigmoid()
    
)

# %%
latent_size = 128
device = 'cpu'

# %%
generator = nn.Sequential(
    
    #in = latent_size,1,1
    nn.ConvTranspose2d(latent_size,256, kernel_size = 4, stride = 1, padding = 0, bias = False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256,4,4

    nn.ConvTranspose2d(256,128, kernel_size = 3, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    #out= 128,7,7

    nn.ConvTranspose2d(128,64, kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    #out = 64,14,14

    nn.ConvTranspose2d(64,8, kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(8),
    nn.ReLU(True),
    #out = 8,28,28

    nn.ConvTranspose2d(8,1, kernel_size = 3, stride = 1, padding = 1, bias = False),
    nn.Tanh()
    #out = 1,28,28
    
)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([128, 1, 28, 28])

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image
import os

# %%
sample_dir = 'generated'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-images-0000.png

# %%
from tqdm import tqdm
import torch.nn.functional as F

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in tqdm(full_image_loader):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0002
epochs = 15

# %%
# %%time
history = fit(epochs, lr)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 547/547 [31:23<00:00,  3.44s/it]
# Epoch [1/15], loss_g: 5.9137, loss_d: 0.0234, real_score: 0.9856, fake_score: 0.0065
# Saving generated-images-0001.png
# 100%|████████████████████████████████████████████████████████████████████████████████| 547/547 [37:03<00:00,  4.06s/it]
# Epoch [2/15], loss_g: 4.9418, loss_d: 0.0535, real_score: 0.9848, fake_score: 0.0346
# Saving generated-images-0002.png
# 100%|████████████████████████████████████████████████████████████████████████████████| 547/547 [27:13<00:00,  2.99s/it]
# Epoch [3/15], loss_g: 5.8262, loss_d: 0.0313, real_score: 0.9795, fake_score: 0.0079
# Saving generated-images-0003.png
# 100%|████████████████████████████████████████████████████████████████████████████████| 547/547 [32:49<00:00,  3.60s/it]
# Epoch [4/15], loss_g: 5.1523, loss_d: 0.0764, real_score: 0.9682, fake_score: 0.0132
# Saving generated-images-0004.png
# ...

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 1, 28, 28])
